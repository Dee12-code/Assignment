# %% [markdown]
# <a href="https://colab.research.google.com/github/Dee12-code/Assignment/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You have a Cinema and your are operating giving tickets based on age.

# %%
age = int(input("Please enter your age: "))
if age < 12:
  price = 300
elif 12<=age<= 17:
  price = 500
elif 18<= age<=59:
  price = 800
else: age>=60
  price = 400
print(f"Your ticket price is {price}")
# Out:
#   File "/tmp/ipython-input-1957647076.py", line 9
#     price = 400
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Number guessing game

# %%
# secret number
secret_number = 54
guess = None
while guess != secret_number:
  guess = int(input("Guess the secret number between 1 and 100: "))

if guess > secret_number:
  print("Too high! Try again.")
elif guess < secret_number:
  print("Too low! Try again.")
else:
  print("Congratulations! You guessed correctly.")
# Out:
# Guess the secret number between 1 and 100: 54
# Congratulations! You guessed correctly.

# %% [markdown]
# Student Grade Calculator

# %%
def calculate_grade(marks):
  if 90<=marks<=100:
    return "A"
  elif 80<=marks<=89:
    return "B"
  elif 70<=marks<=79:
    return "C"
  elif 60<=marks<=69:
    return "D"
  elif 0<=marks<60:
    return "Failed"
  else:
    return "Invalid"
# Ask students to enter their marks
marks = int(input("Enter your marks (0-100):"))
# Call the function and get the grade
grade = calculate_grade(marks)
# print the results
print("Your grade is:",grade)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-863916483.py in <cell line: 0>()
#      13     return "Invalid"
#      14 # Ask students to enter their marks
# ---> 15 marks = int(input("Enter your marks (0-100):"))
#      16 # Call the function and get the grade
#      17 grade = calculate_grade(marks)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...
